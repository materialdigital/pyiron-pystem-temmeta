# %%
#%matplotlib notebook

# %%
from pyiron import Project

# %%
import matplotlib.pyplot as plt

# %%
from tem import pySTEMTEMMETAJob

# %%
pr = Project('tem')

# %%
pr.remove_jobs(recursive=True)

# %%
tem_job = pr.create_job(pySTEMTEMMETAJob, 'tem')

# %%
tem_job.file_name = "./experiment.emd"

# %%
tem_job.plot()

# %%
tem_job.vector = [(35, 101), (205, 101)]

# %%
tem_job.plot()

# %%
tem_job.input
# Out:
#    Parameter                    Value Comment
# 0  file_name         ./experiment.emd
# 1     vector  [(35, 101), (205, 101)]

# %%
tem_job.run()
# Out:
# The job tem was saved and received the ID: 1
# method: direct

# %%
plt.imshow(tem_job._segmentation_labels)

# %%
tem_job.plot_profile()

# %%
tem_job['output/generic/profile']
# Out:
# array([12485, 16075, 21325, 29004, 38002, 44759, 48501, 48820, 43423,
#        37952, 35328, 37140, 43087, 49436, 52335, 49661, 42929, 33294,
#        24268, 18323, 14625, 12598, 11941, 12056, 12966, 16253, 21547,
#        28446, 37481, 44699, 49792, 49631, 45730, 40068, 36353, 37413,
#        42404, 48045, 51254, 49496, 42658, 33785, 24476, 18440, 15129,
#        13899, 13074, 13551, 14183, 17063, 21578, 28085, 36664, 45206,
#        49883, 50706, 46586, 41522, 36926, 38001, 42459, 49005, 53216,
#        52248, 45662, 36197, 27217, 20400, 16299, 15054, 14609, 14134,
#        15475, 17825, 22135, 29699, 37271, 45304, 51683, 52773, 49711,
#        44024, 39361, 38585, 41970, 48293, 53394, 53382, 49618, 40849,
#        32118, 25417, 20730, 18653, 16930, 16396, 16499, 19010, 23741,
#        30038, 38372, 46568, 52202, 54517, 51270, 46834, 42027, 40996,
#        44082, 49344, 54607, 55596, 51519, 43368, 34574, 26505, 22001,
# ...

# %%
pr.job_table()
# Out:
#    id    status chemicalformula  job subjob    projectpath project  \
# 0   1  finished            None  tem   /tem  /home/jovyan/    tem/
#
#                    timestart timestop totalcputime  \
# 0 2020-07-07 19:43:29.137858     None         None
#
#                                                               computer  \
# 0  pyiron@jupyter-ningwang1990-2dpy-2d-2dpystem-2dtemmeta-2dibq3tdr5#1
#
#      hamilton hamversion parentid masterid
# 0  GenericJob        0.4     None     None
